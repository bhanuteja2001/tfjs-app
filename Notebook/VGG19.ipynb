# %%
import pandas as pd # Data analysis and manipultion tool
import numpy as np # Fundamental package for linear algebra and multidimensional arrays
import tensorflow as tf # Deep Learning Tool
import os # OS module in Python provides a way of using operating system dependent functionality
import cv2 # Library for image processing
from sklearn.model_selection import train_test_split # For splitting the data into train and validation set
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from imutils import build_montages
from imutils import paths
import random
import cv2

# %%
Train = pd.read_csv(r"F:\Internshala\Darwin Digibyte\Dataset\DATASET\Notebook\meta_data.csv")
Test = pd.read_csv(r"F:\Internshala\Darwin Digibyte\Dataset\DATASET\Notebook\meta_data_test.csv")

# %%
Train.head()
# Out:
#    Unnamed: 0                                               file  Label
# 0           0  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0
# 1           1  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0
# 2           2  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0
# 3           3  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0
# 4           4  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0

# %%
Test.head(
)
# Out:
#    Unnamed: 0                                               file  Label
# 0           0  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0
# 1           1  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0
# 2           2  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0
# 3           3  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0
# 4           4  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0

# %%
Train.drop(Train.columns[0], axis=1, inplace=True)
Train.head()
# Out:
#                                                 file  Label
# 0  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0
# 1  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0
# 2  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0
# 3  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0
# 4  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0

# %%
Test.drop(Test.columns[0], axis=1, inplace=True)
Test.head()
# Out:
#                                                 file  Label
# 0  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0
# 1  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0
# 2  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0
# 3  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0
# 4  F:\Internshala\Darwin Digibyte\Dataset\DATASET...      0

# %%
data = []
image_size = 224
test_pixel_data = []
import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True


for i in range(len(Train)):
    img_array = Image.open(Train['file'][i])
    new_img_array = np.array(img_array)
    if new_img_array.ndim != 3:
        new_img_array = cv2.cvtColor(new_img_array, cv2.COLOR_GRAY2BGR)
    new_img_array = cv2.resize(new_img_array,(224,224))
    if new_img_array.shape[2] != 3:
        new_img_array = new_img_array[:, :, :3]
    print(i,np.array(new_img_array).shape,Train['Label'][i])
    data.append([new_img_array, Train['Label'][i]])
# Out:
# 0 (224, 224, 3) 0
# 1 (224, 224, 3) 0
# 2 (224, 224, 3) 0
# 3 (224, 224, 3) 0
# 4 (224, 224, 3) 0
# 5 (224, 224, 3) 0
# 6 (224, 224, 3) 0
# 7 (224, 224, 3) 0
# 8 (224, 224, 3) 0
# 9 (224, 224, 3) 0
# 10 (224, 224, 3) 0
# 11 (224, 224, 3) 0
# 12 (224, 224, 3) 0
# 13 (224, 224, 3) 0
# 14 (224, 224, 3) 0
# 15 (224, 224, 3) 0
# 16 (224, 224, 3) 0
# 17 (224, 224, 3) 0
# 18 (224, 224, 3) 0
# 19 (224, 224, 3) 0
# 20 (224, 224, 3) 0
# 21 (224, 224, 3) 0
# 22 (224, 224, 3) 0
# 23 (224, 224, 3) 0
# 24 (224, 224, 3) 0
# 25 (224, 224, 3) 0
# 26 (224, 224, 3) 0
# 27 (224, 224, 3) 0
# 28 (224, 224, 3) 0
# 29 (224, 224, 3) 0
# 30 (224, 224, 3) 0
# 31 (224, 224, 3) 0
# 32 (224, 224, 3) 0
# 33 (224, 224, 3) 0
# 34 (224, 224, 3) 0
# 35 (224, 224, 3) 0
# 36 (224, 224, 3) 0
# 37 (224, 224, 3) 0
# 38 (224, 224, 3) 0
# 39 (224, 224, 3) 0
# 40 (224, 224, 3) 0
# 41 (224, 224, 3) 0
# 42 (224, 224, 3) 0
# 43 (224, 224, 3) 0
# 44 (224, 224, 3) 0
# 45 (224, 224, 3) 0
# 46 (224, 224, 3) 0
# 47 (224, 224, 3) 0
# ...

# %%
for i in range(len(Test)):
    img_array = Image.open(Test['file'][i])
    new_img_array = np.array(img_array)
    if new_img_array.ndim != 3:
        new_img_array = cv2.cvtColor(new_img_array, cv2.COLOR_GRAY2BGR)
    new_img_array = cv2.resize(new_img_array,(224,224))
    if new_img_array.shape[2] != 3:
        new_img_array = new_img_array[:, :, :3]
    print(i,np.array(new_img_array).shape,Test['Label'][i])
    test_pixel_data.append(new_img_array)
# Out:
# 0 (224, 224, 3) 0
# 1 (224, 224, 3) 0
# 2 (224, 224, 3) 0
# 3 (224, 224, 3) 0
# 4 (224, 224, 3) 0
# 5 (224, 224, 3) 0
# 6 (224, 224, 3) 0
# 7 (224, 224, 3) 0
# 8 (224, 224, 3) 0
# 9 (224, 224, 3) 0
# 10 (224, 224, 3) 0
# 11 (224, 224, 3) 0
# 12 (224, 224, 3) 0
# 13 (224, 224, 3) 0
# 14 (224, 224, 3) 0
# 15 (224, 224, 3) 0
# 16 (224, 224, 3) 0
# 17 (224, 224, 3) 0
# 18 (224, 224, 3) 0
# 19 (224, 224, 3) 0
# 20 (224, 224, 3) 0
# 21 (224, 224, 3) 0
# 22 (224, 224, 3) 0
# 23 (224, 224, 3) 0
# 24 (224, 224, 3) 0
# 25 (224, 224, 3) 0
# 26 (224, 224, 3) 0
# 27 (224, 224, 3) 0
# 28 (224, 224, 3) 0
# 29 (224, 224, 3) 0
# 30 (224, 224, 3) 0
# 31 (224, 224, 3) 0
# 32 (224, 224, 3) 0
# 33 (224, 224, 3) 0
# 34 (224, 224, 3) 0
# 35 (224, 224, 3) 0
# 36 (224, 224, 3) 0
# 37 (224, 224, 3) 0
# 38 (224, 224, 3) 0
# 39 (224, 224, 3) 0
# 40 (224, 224, 3) 0
# 41 (224, 224, 3) 0
# 42 (224, 224, 3) 0
# 43 (224, 224, 3) 0
# 44 (224, 224, 3) 0
# 45 (224, 224, 3) 0
# 46 (224, 224, 3) 0
# 47 (224, 224, 3) 0
# ...

# %%
np.random.shuffle(data)
x = []
y = []

counter = 406
count = 0

for image in data:
    try:
        x.append(image[0])
        y.append(image[1])
    except:
        print(count)
    count += 1

# %%
# converting x & y to numpy array as they are list
x = np.array(x)
y = np.array(y)

# %%
pd.Series(y).value_counts()
# Out:
# 2    266
# 4    252
# 0    223
# 1    180
# 3    160
# dtype: int64

# %%
X_train, X_val, y_train, y_val = train_test_split(x,y,test_size=0.2, random_state = 42,stratify=y)

# %%
from keras.utils.np_utils import to_categorical
y_train = to_categorical(y_train)
y_val = to_categorical(y_val)

# %%
test_pixel_data = np.array(test_pixel_data)

test_pixel_data = test_pixel_data/255

print(X_train.shape,X_val.shape,test_pixel_data.shape)
# Out:
# (864, 224, 224, 3) (217, 224, 224, 3) (470, 224, 224, 3)

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1.0/255.0)

val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1.0/255.0)

train_generator = train_datagen.flow(X_train,y_train,batch_size=8)

val_generator = val_datagen.flow(X_val,y_val,batch_size=8)

# %%
print(X_train.shape,y_train.shape,X_val.shape)
# Out:
# (864, 224, 224, 3) (864, 5) (217, 224, 224, 3)

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from keras.layers import *
from keras.models import Sequential
from keras.regularizers import *
from tensorflow.keras.optimizers import Adam

# %%
def build_model():
    model = Sequential()

    conv_base = VGG19(input_shape=(224,224,3), include_top=False, pooling='max',weights='imagenet')
    model.add(conv_base)
    model.add(BatchNormalization())
    model.add(Dense(2048, activation='relu', kernel_regularizer=l1_l2(0.01)))
    model.add(BatchNormalization())
  # model.add(Dense(2048, activation='relu', kernel_regularizer=l1_l2(0.01)))
  # model.add(BatchNormalization())
  # model.add(Dense(2048, activation='relu', kernel_regularizer=l1_l2(0.01)))
  # model.add(BatchNormalization())
  # model.add(Dense(1024, activation='relu', kernel_regularizer=l1_l2(0.01)))
  # model.add(BatchNormalization())
    model.add(Dense(5, activation='softmax'))
    for layer in model.layers:
        layer.trainable = True
 
    model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=1e-4), metrics=['accuracy',"Precision","Recall"])

    return model

# %%
cbs = [tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-5, verbose=0),
tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-6, patience=5, verbose=1, mode='auto')]

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# vgg19 (Functional)           (None, 512)               20024384
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# dense (Dense)                (None, 2048)              1050624
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2048)              8192
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 10245
# ...
# Total params: 21,095,493
# Trainable params: 21,090,373
# Non-trainable params: 5,120
# _________________________________________________________________
# ...

# %%
from time import time

# %%
# %%timeit -n1 -r1 
with tf.device("GPU"):
    model.fit(train_generator,steps_per_epoch=87,epochs=100,validation_data=val_generator,validation_steps=22,callbacks=[cbs])
# Out:
# Epoch 1/100
# 87/87 [==============================] - 63s 559ms/step - loss: 238.0436 - accuracy: 0.3075 - precision: 0.3834 - recall: 0.2055 - val_loss: 221.3251 - val_accuracy: 0.2102 - val_precision: 0.2102 - val_recall: 0.2102
# Epoch 2/100
# 87/87 [==============================] - 49s 559ms/step - loss: 190.0648 - accuracy: 0.4440 - precision: 0.5067 - recall: 0.3247 - val_loss: 173.4110 - val_accuracy: 0.2045 - val_precision: 0.2045 - val_recall: 0.2045
# Epoch 3/100
# 87/87 [==============================] - 48s 551ms/step - loss: 147.2083 - accuracy: 0.4799 - precision: 0.5788 - recall: 0.3693 - val_loss: 128.2386 - val_accuracy: 0.3011 - val_precision: 0.2913 - val_recall: 0.1705
# Epoch 4/100
# 87/87 [==============================] - 49s 556ms/step - loss: 110.2058 - accuracy: 0.5517 - precision: 0.6225 - recall: 0.4454 - val_loss: 95.8675 - val_accuracy: 0.2045 - val_precision: 0.1953 - val_recall: 0.1875
# Epoch 5/100
# ...

# %%
fig, ax  = plt.subplots(2,1)

#Loss
ax[0].plot(model.history.history['loss'], color = 'b', label='Training Loss')
ax[0].plot(model.history.history['val_loss'], color = 'r', label='Validation Loss')
ax[0].legend()
#Accuracy
ax[1].plot(model.history.history['accuracy'], color='b', label='Training Accuraccy')
ax[1].plot(model.history.history['val_accuracy'], color='r', label='Val Accuracy')
ax[1].legend()

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# %%
model.save("F:\\Internshala\\Darwin Digibyte\\Dataset\\DATASET\\weights\\VGG19.h5")

# %%
pred = model.predict(X_val/255)
predictions = np.argmax(pred,axis=1)
test_evaluation = model.evaluate(val_generator)
# Out:
# 28/28 [==============================] - 7s 240ms/step - loss: 0.7154 - accuracy: 0.8848 - precision: 0.9029 - recall: 0.8571 4s - loss: 0.7761 - accuracy: 0.8542 - precision:

# %%
Y_VAL = np.array(list(pd.DataFrame(y_val).idxmax(axis=1)))

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(Y_VAL,predictions))
print(classification_report(Y_VAL,predictions,digits=3))
# Out:
# [[38  1  4  0  2]
#  [ 0 28  1  1  6]
#  [ 1  0 47  0  5]
#  [ 0  1  0 29  2]
#  [ 0  0  1  0 50]]
#               precision    recall  f1-score   support
#
#            0      0.974     0.844     0.905        45
#            1      0.933     0.778     0.848        36
#            2      0.887     0.887     0.887        53
#            3      0.967     0.906     0.935        32
#            4      0.769     0.980     0.862        51
#
#     accuracy                          0.885       217
#    macro avg      0.906     0.879     0.888       217
# weighted avg      0.897     0.885     0.886       217

# %%
conf_matrix = confusion_matrix(Y_VAL,predictions)
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')

plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()
